# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("internship.db")

# %%
query = """
SELECT interns.name AS intern_name,
       interns.track,
       mentors.mentor_name
FROM interns
INNER JOIN mentors
ON interns.track = mentors.track;
"""

# %%
import os
print(os.getcwd())
# Out:
# D:\DS_AI_Internship\src

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'cleaned_dataset.csv', 'customer_orders.csv', 'dashboard.py', 'data.csv', 'data1.csv', 'data1.csv.xlsx', 'day10fundamentals.py', 'day11fundamentals.py', 'day12fundamentals.py', 'day13fundamentals.py', 'day14fundamentals.py', 'day15fundamentals.py', 'day16fundamentals.py', 'day17_database_architect.sql', 'day1fundamentals.py', 'day1_check.py', 'day2fundamentals.py', 'day3fundamentals.py', 'day4fundamentals.py', 'day5fundamentals.py', 'day7fundamentals.py', 'day8fundamentals.py', 'day9fundamentals.py', 'example.xlsx', 'hd.csv', 'internship.db', 'journal.txt', 'location_dirty_data.csv', 'main.py', 'main1.py', 'math_operations.py', 'sample.txt', 'sample_price_data.csv', 'students.csv', 'text_file_demo.py', 'Untitled.ipynb', 'utils.py', '__pycache__']

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(r"C:\sqlite3\internship.db")

# %%
query = "SELECT name FROM sqlite_master WHERE type='table';"
print(pd.read_sql_query(query, conn))
# Out:
#       name
# 0  interns
# 1  mentors

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r"C:\sqlite3\internship.db")

query = "SELECT interns.name AS intern_name, interns.track, mentors.mentor_name FROM interns INNER JOIN mentors ON interns.track = mentors.track;"

df = pd.read_sql_query(query, conn)
df
# Out:
#   intern_name            track mentor_name
# 0   Achinthya     Data Science      Anujna
# 1     Ankitha  Web Development      Akshay
# 2       Anika     Data Science      Anujna
# 3      Anjali  Web Development      Akshay
# 4         Anu             AIML      Ashish
